# %%
# %matplotlib inline

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from pathlib import Path

# %% [markdown]
# # Do we think the same thing is happening in all of these countries?
#
# This is a hypothetical dataset representing pesticide residues above a safety threshold vs. percentage of organic farms in different countries. How can we tell if trends are consistent across countries?

# %%
country_dic={}
for file in Path('.').glob("*.csv"):
    df = pd.read_csv(file)
    x, y = df['x'], df['y']
    x_mean = np.mean(x)
    y_mean = np.mean(y)
    coeff = np.polyfit(x, y, deg=1)
    corr = np.corrcoef(x, y)[0, 1]
    country_dic[file.name[:-4]]={"x-mean":x_mean, "y-mean":y_mean, "lin-reg":(coeff[1], coeff[0]), "r":corr}

    
    print(f"x_mean={x_mean:.3f}, y_mean={y_mean:.3f}, linear regression fr(x)={coeff[1]:.1f} {coeff[0]:.2f} x, r = {corr:.3f} ")
# Out:
# x_mean=54.261, y_mean=47.830, linear regression fr(x)=53.2 -0.10 x, r = -0.062
# x_mean=54.268, y_mean=47.836, linear regression fr(x)=53.8 -0.11 x, r = -0.069
# x_mean=54.269, y_mean=47.831, linear regression fr(x)=53.8 -0.11 x, r = -0.069
# x_mean=54.266, y_mean=47.831, linear regression fr(x)=53.8 -0.11 x, r = -0.069
# x_mean=54.267, y_mean=47.838, linear regression fr(x)=53.8 -0.11 x, r = -0.068
# x_mean=54.267, y_mean=47.840, linear regression fr(x)=53.3 -0.10 x, r = -0.063
# x_mean=54.263, y_mean=47.832, linear regression fr(x)=53.5 -0.10 x, r = -0.064
# x_mean=54.260, y_mean=47.840, linear regression fr(x)=53.6 -0.11 x, r = -0.066
# x_mean=54.260, y_mean=47.840, linear regression fr(x)=53.1 -0.10 x, r = -0.060
# x_mean=54.270, y_mean=47.837, linear regression fr(x)=53.9 -0.11 x, r = -0.069
# x_mean=54.269, y_mean=47.835, linear regression fr(x)=53.8 -0.11 x, r = -0.069
# x_mean=54.266, y_mean=47.835, linear regression fr(x)=53.4 -0.10 x, r = -0.064
# x_mean=54.267, y_mean=47.832, linear regression fr(x)=53.6 -0.11 x, r = -0.067

# %%
print(country_dic)
# Out:
# {'Algerra': {'x-mean': 54.261441783514094, 'y-mean': 47.830251913635216, 'lin-reg': (53.21108723737494, -0.09916498985057502), 'r': -0.0617148379566778}, 'Belmara': {'x-mean': 54.2678488233662, 'y-mean': 47.835896330588206, 'lin-reg': (53.849707743907715, -0.11081720657278302), 'r': -0.06897973536063176}, 'Brunovia': {'x-mean': 54.268730022378875, 'y-mean': 47.830823155217814, 'lin-reg': (53.80947081136492, -0.11016745101058531), 'r': -0.06858639425794844}, 'Cyrdania': {'x-mean': 54.26588178560211, 'y-mean': 47.83149565202444, 'lin-reg': (53.812595647986875, -0.11021842452672266), 'r': -0.06860920644502211}, 'Elandia': {'x-mean': 54.267319706173936, 'y-mean': 47.83771726721831, 'lin-reg': (53.79704498505449, -0.1098142998420132), 'r': -0.06834335645012028}, 'Ivoria': {'x-mean': 54.26734110449506, 'y-mean': 47.839545225097886, 'lin-reg': (53.326678726036754, -0.10111299704868638), 'r': -0.06296110022682305}, 'Kaslovia': {'x-mean': 54.26327323943662, 'y-mean': 47.832252816901416, 'lin-reg': (53.45297844922924, -0.10358250243265636), 'r': -0.06447185270095167}, 'Lazkova': {'x-mean': 54.26015033403803, 'y-mean': 47.839717279160425, 'lin-reg': (53.55422625106994, -0.1053168658164361), 'r': -0.06558333731006559}, 'Marensia': {'x-mean': 54.26030345121761, 'y-mean': 47.83982920875564, 'lin-reg': (53.098341946502224, -0.09691270419219478), 'r': -0.060341441993538567}, 'Montabria': {'x-mean': 54.26992723102747, 'y-mean': 47.83698798816881, 'lin-reg': (53.89084339369225, -0.11155082961051638), 'r': -0.06944556959817216}, 'Norvaska': {'x-mean': 54.26880527974154, 'y-mean': 47.83545020393662, 'lin-reg': (53.80879316302432, -0.11006954968506623), 'r': -0.06850422050586687}, 'Santorvia': {'x-mean': 54.266099784204926, 'y-mean': 47.83472062488412, 'lin-reg': (53.42513004546028, -0.10301844877017205), 'r': -0.06412835215474479}, 'Serbeka': {'x-mean': 54.266916301257034, 'y-mean': 47.831601988006156, 'lin-reg': (53.63494893503814, -0.10694079086446226), 'r': -0.06657523019998103}}

# %%
for file in Path('.').glob("*.csv"):
    df = pd.read_csv(file)
    x, y = df['x'], df['y']
    name=file.name[:-4]
    label=str(name)
    name=plt.scatter(x,y)
    plt.title(label)
    plt.show()
